# %%
#Applied Data Analytics II – Course Project 
#Date completed: 02-05-2020 
#Research question: Bike Sharing Demand
#Document name: Notebook

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# Dataset links: https://www.kaggle.com/c/bike-sharing-demand/data

# %% [markdown]
# We need to download "train.cvs" and "test.cvs" from the given links.
#
# The training set is comprised of the first 19 days of each month, while the test set is the 20th to the end of the month.
#
# We want to predict the total count of bikes rented during each hour covered by the test set, using only information available prior to the rental period.

# %% [markdown]
# # Load Libraries

# %%
# %matplotlib inline

import numpy as np
import pandas as pd 
from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt

import seaborn as sns
sns.set(style='whitegrid' , palette='tab10')

# %% [markdown]
# # Load Dataset

# %%
train = pd.read_csv('bikesharingdemand_train.csv')

# %%
test=pd.read_csv('bikesharingdemand_test.csv')

# %% [markdown]
# # Understand data structure

# %%
train.shape
# Out:
# (10886, 12)

# %%
test.shape
# Out:
# (6493, 9)

# %%
#Check description statistics figures of training data
train.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
#Check description statistics figures of training data
test.describe()
# Out:
#             season      holiday   workingday      weather         temp  \
# count  6493.000000  6493.000000  6493.000000  6493.000000  6493.000000
# mean      2.493300     0.029108     0.685815     1.436778    20.620607
# std       1.091258     0.168123     0.464226     0.648390     8.059583
# min       1.000000     0.000000     0.000000     1.000000     0.820000
# 25%       2.000000     0.000000     0.000000     1.000000    13.940000
# 50%       3.000000     0.000000     1.000000     1.000000    21.320000
# 75%       3.000000     0.000000     1.000000     2.000000    27.060000
# max       4.000000     1.000000     1.000000     4.000000    40.180000
#
#              atemp     humidity    windspeed
# count  6493.000000  6493.000000  6493.000000
# mean     24.012865    64.125212    12.631157
# std       8.782741    19.293391     8.250151
# min       0.000000    16.000000     0.000000
# 25%      16.665000    49.000000     7.001500
# 50%      25.000000    65.000000    11.001400
# ...

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %% [markdown]
# # Data Preprocessing

# %%
#Check missing values of training data
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
#Check missing values of testing data
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    6493 non-null   object
#  1   season      6493 non-null   int64
#  2   holiday     6493 non-null   int64
#  3   workingday  6493 non-null   int64
#  4   weather     6493 non-null   int64
#  5   temp        6493 non-null   float64
#  6   atemp       6493 non-null   float64
#  7   humidity    6493 non-null   int64
#  8   windspeed   6493 non-null   float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 456.7+ KB

# %% [markdown]
# The dataset does not contain missing values, however, it does not mean that it does not contain outliers.

# %% [markdown]
# By understanding the descriptive statistical figures, I notice that the standard deviation of count is higher than other figures, therefore I hope to observe its distribution.

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
fig.set_size_inches(6,5)

sns.distplot(train['count'])

ax.set(xlabel='count',title='Distribution of count',)
# Out:
# [Text(0.5, 0, 'count'), Text(0.5, 1.0, 'Distribution of count')]

# %% [markdown]
# I excluded all the data that are beyond three standard deviation.

# %%
train_WithoutOutliers = train[np.abs(train['count']-
                        train['count'].mean())<=(3*train['count'].std())] 
train_WithoutOutliers .shape
# Out:
# (10739, 12)

# %%
train_WithoutOutliers['count'] .describe()
# Out:
# count    10739.000000
# mean       183.003818
# std        166.681429
# min          1.000000
# 25%         41.000000
# 50%        141.000000
# 75%        276.000000
# max        734.000000
# Name: count, dtype: float64

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
fig.set_size_inches(12,5)

sns.distplot(train_WithoutOutliers['count'],ax=ax1)
sns.distplot(train['count'],ax=ax2)

ax1.set(xlabel='count',title='Distribution of count without outliers',)
ax2.set(xlabel='registered',title='Distribution of count')
# Out:
# [Text(0.5, 0, 'registered'), Text(0.5, 1.0, 'Distribution of count')]

# %% [markdown]
# In order to avoid overfitting, I used log algorithm to do data transformation.

# %%
yLabels=train_WithoutOutliers['count']
yLabels_log=np.log(yLabels)
sns.distplot(yLabels_log)

# %% [markdown]
# Because testing dataset does not contain count variables, I need not to perform the same algorithoms.

# %% [markdown]
# #### Data combination

# %%
All=pd.concat([train_WithoutOutliers,test],ignore_index=True)

# %%
All.shape
# Out:
# (17232, 12)

# %%
All.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0     3.0        13.0   16.0
# 1        80        0.0     8.0        32.0   40.0
# 2        80        0.0     5.0        27.0   32.0
# 3        75        0.0     3.0        10.0   13.0
# 4        75        0.0     0.0         1.0    1.0

# %% [markdown]
# # Data visualizations

# %% [markdown]
# In order to visualize the data earsier, I splitted the variable "datetime" into date, hour, year, month, weekday.

# %%
All['date']=All.datetime.apply( lambda c : c.split( )[0])
All['hour']=All.datetime.apply( lambda c : c.split( )[1].split(':')[0]).astype('int')
All['year']=All.datetime.apply( lambda c : c.split( )[0].split('-')[0]).astype('int')
All['month']=All.datetime.apply( lambda c : c.split( )[0].split('-')[1]).astype('int')
All['weekday']=All.date.apply( lambda c : datetime.strptime(c,'%Y-%m-%d').isoweekday())

All.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count        date  hour  year  \
# 0        81        0.0     3.0        13.0   16.0  2011-01-01     0  2011
# 1        80        0.0     8.0        32.0   40.0  2011-01-01     1  2011
# 2        80        0.0     5.0        27.0   32.0  2011-01-01     2  2011
# 3        75        0.0     3.0        10.0   13.0  2011-01-01     3  2011
# 4        75        0.0     0.0         1.0    1.0  2011-01-01     4  2011
#
#    month  weekday
# 0      1        6
# 1      1        6
# ...

# %% [markdown]
# #### Overall observation

# %% [markdown]
# I used scatter charts to check the relationship between the predicted values and other features.

# %%
sns.pairplot(All ,x_vars=['holiday','workingday','weather','season',
                                'weekday','hour','year','month','windspeed','humidity','temp','atemp'] ,
                        y_vars=['casual','registered','count'] , plot_kws={'alpha': 0.1})

# %% [markdown]
# I used correlation matrix to check each features and hourly rentals count.

# %%
corrDf = All.corr() 
corrDf['count'].sort_values(ascending =False)
# Out:
# count         1.000000
# registered    0.966209
# casual        0.704764
# hour          0.405437
# temp          0.385954
# atemp         0.381967
# year          0.234959
# month         0.164673
# season        0.159801
# windspeed     0.106074
# weekday       0.022602
# holiday       0.002978
# workingday   -0.020764
# weather      -0.127519
# humidity     -0.317028
# Name: count, dtype: float64

# %%
plt.figure(figsize=(16,8))
sns.heatmap(All.corr(), annot=True)
plt.show()

# %% [markdown]
# #### Individual observation

# %% [markdown]
# ##### Hour and rentals count

# %%
workingday_df=All[All['workingday']==1]
workingday_df = workingday_df.groupby(['hour'], as_index=True).agg({'casual':'mean',
                                                                    'registered':'mean',
                                                                    'count':'mean'})

nworkingday_df=All[All['workingday']==0]
nworkingday_df = nworkingday_df.groupby(['hour'], as_index=True).agg({'casual':'mean',
                                                                      'registered':'mean', 
                                                                      'count':'mean'})
fig, axes = plt.subplots(1, 2,sharey = True)

workingday_df.plot(figsize=(15,5),title = 'The average number of rentals initiated per hour in the working day',ax=axes[0])
nworkingday_df.plot(figsize=(15,5),title = 'The average number of rentals initiated per hour in the nonworkdays',ax=axes[1])

# %% [markdown]
# ##### temp and rentals count

# %%
temp_df = All.groupby(['date','weekday'], as_index=False).agg({'year':'mean',
                                                                     'month':'mean',
                                                                     'temp':'median'})
# Drop missing values in testing data
temp_df.dropna ( axis = 0 , how ='any', inplace = True )

temp_month = temp_df.groupby(['year','month'], as_index=False).agg({'weekday':'min',
                                                                    'temp':'median'})

temp_df['date']=pd.to_datetime(temp_df['date'])

temp_month.rename(columns={'weekday':'day'},inplace=True)
temp_month['date']=pd.to_datetime(temp_month[['year','month','day']])

fig = plt.figure(figsize=(18,6))
ax = fig.add_subplot(1,1,1)

plt.plot(temp_df['date'] , temp_df['temp'] , linewidth=1.3 , label='Daily average')
ax.set_title('Change trend of average temperature per day in two years')
plt.plot(temp_month['date'] , temp_month['temp'] , marker='o', linewidth=1.3 ,
         label='Monthly average')
ax.legend()

# %%
temp_rentals = All.groupby(['temp'], as_index=True).agg({'casual':'mean', 'registered':'mean','count':'mean'})
temp_rentals .plot(title = 'The average number of rentals initiated per hour changes with the temperature')

# %% [markdown]
# ##### Humidity and rentals count

# %%
humidity_df = All.groupby('date', as_index=False).agg({'humidity':'mean'})
humidity_df['date']=pd.to_datetime(humidity_df['date'])

humidity_df=humidity_df.set_index('date')

humidity_month = All.groupby(['year','month'], as_index=False).agg({'weekday':'min','humidity':'mean'})
humidity_month.rename(columns={'weekday':'day'},inplace=True)
humidity_month['date']=pd.to_datetime(humidity_month[['year','month','day']])

fig = plt.figure(figsize=(18,6))
ax = fig.add_subplot(1,1,1)
plt.plot(humidity_df.index , humidity_df['humidity'] , linewidth=1.3,label='Daily average')
plt.plot(humidity_month['date'], humidity_month['humidity'] ,marker='o', 
         linewidth=1.3,label='Monthly average')
ax.legend()
ax.set_title('Change trend of average humidity per day in two years')
# Out:
# Text(0.5, 1.0, 'Change trend of average humidity per day in two years')

# %%
humidity_rentals = All.groupby(['humidity'], as_index=True).agg({'casual':'mean','registered':'mean','count':'mean'})
humidity_rentals .plot (title = 'Average number of rentals initiated per hour in different humidity')

# %% [markdown]
# ##### Year, month and rentals count

# %%
# Drop missing values in testing dataset
count_df = All.groupby(['date','weekday'], as_index=False).agg({'year':'mean',
                                                                      'month':'mean',
                                                                      'casual':'sum',
                                                                      'registered':'sum',
                                                                       'count':'sum'})

count_df.dropna ( axis = 0 , how ='any', inplace = True )

count_month = count_df.groupby(['year','month'], as_index=False).agg({'weekday':'min','casual':'mean', 'registered':'mean','count':'mean'})

count_df['date']=pd.to_datetime(count_df['date'])

count_month.rename(columns={'weekday':'day'},inplace=True)
count_month['date']=pd.to_datetime(count_month[['year','month','day']])

fig = plt.figure(figsize=(18,6))
ax = fig.add_subplot(1,1,1)

plt.plot(count_month['date'] , count_month['count'] , marker='o', 
         linewidth=1.3 , label='Monthly average')
ax.legend()

# %%
import matplotlib.pyplot as plt
import seaborn as sn

sn.boxplot(All['year'],All['count'])
plt.title("The influence of year")
plt.show()

# %% [markdown]
# ##### Season and rentals count

# %%
import matplotlib.pyplot as plt
import seaborn as sn

sn.boxplot(All['season'],All['count'])
plt.title("The influence of season")
plt.show()

# %% [markdown]
# ##### Weather and rentals count

# %%
count_weather = All.groupby('weather')

count_weather[['casual','registered','count']].count()
# Out:
#          casual  registered  count
# weather
# 1          7076        7076   7076
# 2          2809        2809   2809
# 3           853         853    853
# 4             1           1      1

# %%
weather_df = All.groupby('weather', as_index=True).agg({'casual':'mean','registered':'mean'})

weather_df.plot.bar(stacked=True,title = 'Average number of rentals initiated per hour in different weather')

# %%
sn.boxplot(All['weather'],All['count'])
plt.title("The influence of weather")
plt.show()

# %%
All[All['weather']==4]
# Out:
#                   datetime  season  holiday  workingday  weather  temp  \
# 5631   2012-01-09 18:00:00       1        0           1        4  8.20
# 10893  2011-01-26 16:00:00       1        0           1        4  9.02
# 13987  2012-01-21 01:00:00       1        0           0        4  5.74
#
#         atemp  humidity  windspeed  casual  registered  count        date  \
# 5631   11.365        86     6.0032     6.0       158.0  164.0  2012-01-09
# 10893   9.850        93    22.0028     NaN         NaN    NaN  2011-01-26
# 13987   6.820        86    12.9980     NaN         NaN    NaN  2012-01-21
#
#        hour  year  month  weekday
# 5631     18  2012      1        1
# 10893    16  2011      1        3
# 13987     1  2012      1        6

# %% [markdown]
# ##### Wind speed and rentals count

# %%
windspeed_df = All.groupby('date', as_index=False).agg({'windspeed':'mean'})
windspeed_df['date']=pd.to_datetime(windspeed_df['date'])

windspeed_df=windspeed_df.set_index('date')

windspeed_month = All.groupby(['year','month'], as_index=False).agg({'weekday':'min','windspeed':'mean'})
windspeed_month.rename(columns={'weekday':'day'},inplace=True)
windspeed_month['date']=pd.to_datetime(windspeed_month[['year','month','day']])

fig = plt.figure(figsize=(18,6))
ax = fig.add_subplot(1,1,1)

plt.plot(windspeed_df.index , windspeed_df['windspeed'], linewidth=1.3,label='Daily average')
plt.plot(windspeed_month['date'], windspeed_month['windspeed'], marker='o', linewidth=1.3,label='Monthly average')

ax.legend()
ax.set_title('Change trend of average number of windspeed  per day in two years')
# Out:
# Text(0.5, 1.0, 'Change trend of average number of windspeed  per day in two years')

# %%
windspeed_rentals = All.groupby(['windspeed'], as_index=True).agg({'casual':'max', 'registered':'max', 'count':'max'})

windspeed_rentals .plot(title = 'Max number of rentals initiated per hour in different windspeed')

# %%
df2=All[All['windspeed']>40]
df2=df2[df2['count']>400]
df2
# Out:
#                  datetime  season  holiday  workingday  weather   temp  atemp  \
# 6515  2012-03-08 17:00:00       1        0           1        1  25.42  31.06
#
#       humidity  windspeed  casual  registered  count        date  hour  year  \
# 6515        38    43.9989    52.0       545.0  597.0  2012-03-08    17  2012
#
#       month  weekday
# 6515      3        4

# %% [markdown]
# ##### Date and rentals count

# %%
day_df = All.groupby(['date'], as_index=False).agg({'casual':'sum','registered':'sum','count':'sum', 'workingday':'mean','weekday':'mean','holiday':'mean','year':'mean'})

day_df.head()
# Out:
#          date  casual  registered   count  workingday  weekday  holiday  year
# 0  2011-01-01   331.0       654.0   985.0           0        6        0  2011
# 1  2011-01-02   131.0       670.0   801.0           0        7        0  2011
# 2  2011-01-03   120.0      1229.0  1349.0           1        1        0  2011
# 3  2011-01-04   108.0      1454.0  1562.0           1        2        0  2011
# 4  2011-01-05    82.0      1518.0  1600.0           1        3        0  2011

# %%
number_pei=day_df[['casual','registered']].mean()

number_pei
# Out:
# casual         517.411765
# registered    2171.067031
# dtype: float64

# %%
plt.axes(aspect='equal')  
plt.pie(number_pei, labels=['casual','registered'], autopct='%1.1f%%', 
        pctdistance=0.6 , labeldistance=1.05 , radius=1 )  
plt.title('Casual or registered in the total lease')
# Out:
# Text(0.5, 1.0, 'Casual or registered in the total lease')

# %% [markdown]
# ###### Working days and rentals count

# %%
workingday_df=day_df.groupby(['workingday'], as_index=True).agg({'casual':'mean', 'registered':'mean'})
workingday_df_0 = workingday_df.loc[0]
workingday_df_1 = workingday_df.loc[1]

fig = plt.figure(figsize=(8,6)) 
plt.subplots_adjust(hspace=0.5, wspace=0.2)
grid = plt.GridSpec(2, 2, wspace=0.5, hspace=0.5)

plt.subplot2grid((2,2),(1,0), rowspan=2)
width = 0.3

p1 = plt.bar(workingday_df.index,workingday_df['casual'], width)
p2 = plt.bar(workingday_df.index,workingday_df['registered'], 
             width,bottom=workingday_df['casual'])
plt.title('Average number of rentals initiated per day')
plt.xticks([0,1], ('nonworking day', 'working day'),rotation=20)
plt.legend((p1[0], p2[0]), ('casual', 'registered'))

plt.subplot2grid((2,2),(0,0))
plt.pie(workingday_df_0, labels=['casual','registered'], autopct='%1.1f%%', 
        pctdistance=0.6 , labeldistance=1.35 , radius=1.3)
plt.axis('equal') 
plt.title('nonworking day')

plt.subplot2grid((2,2),(0,1))
plt.pie(workingday_df_1, labels=['casual','registered'], autopct='%1.1f%%', 
        pctdistance=0.6 , labeldistance=1.35 , radius=1.3)
plt.title('working day')
plt.axis('equal')
# Out:
# (-1.4377319238880382,
#  1.4303681868518114,
#  -1.4388719783705668,
#  1.4372896952393586)

# %%
weekday_df= day_df.groupby(['weekday'], as_index=True).agg({'casual':'mean', 'registered':'mean'})
weekday_df.plot.bar(stacked=True , title = 'Average number of rentals initiated per day by weekday')

# %% [markdown]
# ###### Holidays and rentals count

# %%
holiday_count=day_df.groupby('year', as_index=True).agg({'holiday':'sum'})
holiday_count
# Out:
#       holiday
# year
# 2011       10
# 2012       11

# %%
holiday_df = day_df.groupby('holiday', as_index=True).agg({'casual':'mean', 'registered':'mean'})
holiday_df.plot.bar(stacked=True , title = 'Average number of rentals initiated per day by holiday or not')

# %% [markdown]
# #### Remove a random 10% from the original dataset

# %%
import pandas as pd

All=pd.concat([train_WithoutOutliers,test],ignore_index=True)

df = pd.DataFrame(All)

df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 17227  2012-12-31 19:00:00       1        0           1        2  10.66
# 17228  2012-12-31 20:00:00       1        0           1        2  10.66
# 17229  2012-12-31 21:00:00       1        0           1        1  10.66
# 17230  2012-12-31 22:00:00       1        0           1        1  10.66
# 17231  2012-12-31 23:00:00       1        0           1        1  10.66
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
Sample = df.sample(frac=0.9)

# %%
Sample
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 7577   2012-05-15 22:00:00       2        0           1        1  23.78
# 350    2011-01-16 02:00:00       1        0           0        1  10.66
# 10024  2012-11-09 03:00:00       4        0           1        1  13.12
# 16770  2012-11-23 15:00:00       4        0           1        1  19.68
# 12227  2011-06-28 00:00:00       3        0           1        2  27.06
# ...                    ...     ...      ...         ...      ...    ...
# 3112   2011-07-18 14:00:00       3        0           1        1  33.62
# 4039   2011-09-19 08:00:00       3        0           1        2  21.32
# 12180  2011-06-26 01:00:00       3        0           0        1  26.24
# 13742  2011-12-22 17:00:00       1        0           1        2  18.04
# 6343   2012-03-01 13:00:00       1        0           1        1  23.78
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# #### Feature Engineering

# %%
Sample['date']=Sample.datetime.apply( lambda c : c.split( )[0])
Sample['hour']=Sample.datetime.apply( lambda c : c.split( )[1].split(':')[0]).astype('int')
Sample['year']=Sample.datetime.apply( lambda c : c.split( )[0].split('-')[0]).astype('int')
Sample['month']=Sample.datetime.apply( lambda c : c.split( )[0].split('-')[1]).astype('int')
Sample['weekday']=Sample.date.apply( lambda c : datetime.strptime(c,'%Y-%m-%d').isoweekday())

Sample.head()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 7577   2012-05-15 22:00:00       2        0           1        1  23.78
# 350    2011-01-16 02:00:00       1        0           0        1  10.66
# 10024  2012-11-09 03:00:00       4        0           1        1  13.12
# 16770  2012-11-23 15:00:00       4        0           1        1  19.68
# 12227  2011-06-28 00:00:00       3        0           1        2  27.06
#
#         atemp  humidity  windspeed  casual  registered  count        date  \
# 7577   27.275        78    15.0013     9.0        74.0   83.0  2012-05-15
# 350    14.395        56     6.0032     3.0        13.0   16.0  2011-01-16
# 10024  14.395        53    27.9993     3.0         6.0    9.0  2012-11-09
# 16770  23.485        41    16.9979     NaN         NaN    NaN  2012-11-23
# 12227  30.305        78     8.9981     NaN         NaN    NaN  2011-06-28
#
#        hour  year  month  weekday
# 7577     22  2012      5        2
# ...

# %% [markdown]
# ##### Coercing To Categorical Type

# %%
Sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15509 entries, 7577 to 6343
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    15509 non-null  object
#  1   season      15509 non-null  int64
#  2   holiday     15509 non-null  int64
#  3   workingday  15509 non-null  int64
#  4   weather     15509 non-null  int64
#  5   temp        15509 non-null  float64
#  6   atemp       15509 non-null  float64
#  7   humidity    15509 non-null  int64
#  8   windspeed   15509 non-null  float64
#  9   casual      9668 non-null   float64
#  10  registered  9668 non-null   float64
#  11  count       9668 non-null   float64
#  12  date        15509 non-null  object
#  13  hour        15509 non-null  int32
#  14  year        15509 non-null  int32
#  15  month       15509 non-null  int32
#  16  weekday     15509 non-null  int64
# dtypes: float64(6), int32(3), int64(6), object(2)
# memory usage: 2.0+ MB

# %%
# In the word document, I have analyzed the categorical variables and numerical variables

categoricalFeatureNames = ["season","holiday","workingday","weather","weekday","month","year","hour"]
numericalFeatureNames = ["temp","humidity","windspeed","atemp"]
dropFeatures = ['casual',"count","datetime","date","registered"]

# %%
# Use pd.get_dummies to conduct one-hot encoding

dummies_month = pd.get_dummies(Sample['month'], prefix= 'month')
dummies_season=pd.get_dummies(Sample['season'],prefix='season')
dummies_weather=pd.get_dummies(Sample['weather'],prefix='weather')
dummies_year=pd.get_dummies(Sample['year'],prefix='year')
dummies_holiday=pd.get_dummies(Sample['holiday'],prefix='holiday')
dummies_workingday=pd.get_dummies(Sample['workingday'],prefix='workingday')
dummies_weekday=pd.get_dummies(Sample['weekday'],prefix='weekday')
dummies_hour = pd.get_dummies(Sample['hour'], prefix= 'hour')

# %%
# Combine the new factors

Sample_2=pd.concat([Sample,dummies_month,dummies_season,dummies_weather,dummies_year,dummies_holiday,dummies_workingday,dummies_weekday,dummies_hour],axis=1)

# %% [markdown]
# #### Split Training And Testing Data

# %%
dataTrain = Sample_2[pd.notnull(Sample_2['count'])]
dataTest= Sample_2[~pd.notnull(Sample_2['count'])].sort_values(by=['datetime'])
datetimecol = dataTest['datetime']
yLabels=dataTrain['count']
yLabels_log=np.log(yLabels)

# %% [markdown]
# #### Dropping Unncessary Variables

# %%
dataTrain  = dataTrain.drop(dropFeatures,axis=1)
dataTest  = dataTest.drop(dropFeatures,axis=1)

# %% [markdown]
# #### RMSLE Scorer

# %%
def rmsle(y, y_,convertExp=True):
    if convertExp:
        y = np.exp(y),
        y_ = np.exp(y_)
    log1 = np.nan_to_num(np.array([np.log(v + 1) for v in y]))
    log2 = np.nan_to_num(np.array([np.log(v + 1) for v in y_]))
    calc = (log1 - log2) ** 2
    return np.sqrt(np.mean(calc))

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
import warnings
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore", category=DeprecationWarning)

lModel = LinearRegression()

yLabelsLog = np.log1p(yLabels)
lModel.fit(X = dataTrain,y = yLabelsLog)

preds = lModel.predict(X= dataTrain)
print ("RMSLE Value For Linear Regression: ",rmsle(np.exp(yLabelsLog),np.exp(preds),False))
# Out:
# RMSLE Value For Linear Regression:  0.5556190747919039

# %% [markdown]
# # Regularization Model - Ridge

# %%
RidgeModel = Ridge()

yLabelsLog = np.log1p(yLabels)
RidgeModel.fit(dataTrain,yLabelsLog)

preds = RidgeModel.predict(X= dataTrain)
print ("RMSLE Value For Ridge Regression: ",rmsle(np.exp(yLabelsLog),np.exp(preds),False))
# Out:
# RMSLE Value For Ridge Regression:  0.5555464793231847

# %% [markdown]
# # Regularization Model - Lasso

# %%
LassoModel = Lasso()

yLabelsLog = np.log1p(yLabels)
LassoModel.fit(dataTrain,yLabelsLog)

preds = LassoModel.predict(X= dataTrain)
print ("RMSLE Value For Lasso Regression: ",rmsle(np.exp(yLabelsLog),np.exp(preds),False))
# Out:
# RMSLE Value For Lasso Regression:  1.0229624453514283

# %% [markdown]
# # Ensemble Models - Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rfModel = RandomForestRegressor(n_estimators=200,random_state=42)
yLabelsLog = np.log1p(yLabels)
rfModel.fit(dataTrain,yLabelsLog)
preds = rfModel.predict(X= dataTrain)
print ("RMSLE Value For Random Forest: ",rmsle(np.exp(yLabelsLog),np.exp(preds),False))
# Out:
# RMSLE Value For Random Forest:  0.10426971851401805

# %% [markdown]
# # Ensemble Model - Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbm = GradientBoostingRegressor(n_estimators=100,alpha=0.01); 
yLabelsLog = np.log1p(yLabels)
gbm.fit(dataTrain,yLabelsLog)
preds = gbm.predict(X= dataTrain)
print ("RMSLE Value For Gradient Boost: ",rmsle(np.exp(yLabelsLog),np.exp(preds),False))
# Out:
# RMSLE Value For Gradient Boost:  0.41054422370624716

# %% [markdown]
# # Ensemble Model - Bagging Regressor

# %%
from sklearn.ensemble import BaggingRegressor
bgr = BaggingRegressor(n_estimators=100); 
yLabelsLog = np.log1p(yLabels)
bgr.fit(dataTrain,yLabelsLog)
preds = bgr.predict(X= dataTrain)
print ("RMSLE Value For BaggingRegressor: ",rmsle(np.exp(yLabelsLog),np.exp(preds),False))
# Out:
# RMSLE Value For BaggingRegressor:  0.10583439053851548

# %% [markdown]
# # Ensemble Model - AdaBoost Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor
adr = AdaBoostRegressor(n_estimators=100); 
yLabelsLog = np.log1p(yLabels)
adr.fit(dataTrain,yLabelsLog)
preds = adr.predict(X= dataTrain)
print ("RMSLE Value For AdaBoostRegressor: ",rmsle(np.exp(yLabelsLog),np.exp(preds),False))
# Out:
# RMSLE Value For AdaBoostRegressor:  0.6552913709364451

# %% [markdown]
# # KNeighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

KNR = KNeighborsRegressor(); 
yLabelsLog = np.log1p(yLabels)
KNR.fit(dataTrain,yLabelsLog)
preds = KNR.predict(X= dataTrain)
print ("RMSLE Value For KNeighborsRegressor: ",rmsle(np.exp(yLabelsLog),np.exp(preds),False))
# Out:
# RMSLE Value For KNeighborsRegressor:  0.5676339799365299

# %% [markdown]
# I compared the distribution of training and testing results. More or less the distribution of training and testing looks identical. It confirms visually that the model has not predicted really bad and not suffering from major overfitting problem.

# %%
predsTest = rfModel.predict(X= dataTest)
fig,(ax1,ax2)= plt.subplots(ncols=2)
fig.set_size_inches(12,5)
sn.distplot(yLabels,ax=ax1,bins=50)
sn.distplot(np.exp(predsTest),ax=ax2,bins=50)

# %% [markdown]
# # Conclusion

# %% [markdown]
# Random forest performs the best among the eight models I have applied. The RMSLE is not large and it basically predicts the dependent variables well.

# %% [markdown]
# Hours play the most significant part in bike usages. Temperature, season factors also have an enormous impact on the bike usages. If the enterprises can consider these factors to increase use ratio of sharing bikes, they will lower the costs and increase their profits.

# %% [markdown]
# Based on the two years’ data, casual users are far fewer than registered users. If the companies can attract the casual users to use their services, they are able to increase demand.

# %% [markdown]
# # Improvements

# %% [markdown]
# Data cleaning plays an indispensable role in machine learning, which may even affect the model results. This dataset is almost completed and need not to fill in missing values, which is marvelous. However, I merely handle y label outliers due to the time. If I can deal with the outliers of the wind speed or weather, the model may perform better.

# %% [markdown]
# Even though I analyzed the relationship pf each variable and the dependent variable, I took all the factors into consideration while building the models. However, some of the factors may not be strongly correlated to the dependent variables. What is more, some of the features can be combined together to train the model such as “temp” and “atemp”, yet I did not perform this function.

# %% [markdown]
# Dimensionality reduction or MinMaxScaler is largely possible to improve the model. I did not perform these algorithms while I performed data preprocessing.

# %% [markdown]
# I used four ensemble algorithms in my notebook, I intended to use xgBoost, lightGBM and MLP Regressor but did not have enough time, these algorithms may perform better than random forest.
